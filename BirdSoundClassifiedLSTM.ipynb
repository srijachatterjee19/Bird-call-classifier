# %%
# install tensor flow
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (2.13.0rc1)
# Requirement already satisfied: tensorflow-macos==2.13.0-rc1 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.13.0rc1)
# Requirement already satisfied: packaging in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (22.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (2.13.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (16.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (2.3.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (23.5.26)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (4.4.0)
# Requirement already satisfied: six>=1.12.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (3.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (0.4.0)
# Requirement already satisfied: keras<2.14,>=2.13.1rc0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (2.13.1rc0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (3.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.14.1)
# Requirement already satisfied: numpy>=1.22 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.23.5)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0rc0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (2.13.0rc0)
# Requirement already satisfied: setuptools in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (65.6.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (4.23.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.54.2)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0-rc1->tensorflow) (0.38.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (0.7.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2.20.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2.2.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (5.3.1)
# Requirement already satisfied: urllib3<2.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (1.26.14)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (3.2.2)

# %%
# install version 3.5.2 to enable subplots 
# !pip install matplotlib==3.5.2 --user
# Out:
# Requirement already satisfied: matplotlib==3.5.2 in /Users/srijachatterjee/.local/lib/python3.10/site-packages (3.5.2)
# Requirement already satisfied: cycler>=0.10 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from matplotlib==3.5.2) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from matplotlib==3.5.2) (1.23.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from matplotlib==3.5.2) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from matplotlib==3.5.2) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from matplotlib==3.5.2) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from matplotlib==3.5.2) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from matplotlib==3.5.2) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from matplotlib==3.5.2) (4.25.0)
# Requirement already satisfied: six>=1.5 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.5.2) (1.16.0)

# %%
print(matplotlib.__version__)
# Out:
# 3.5.2

# %%
# install version 3.5.2 to enable subplots 
# !pip install librosa==0.9.1
# Out:
# Requirement already satisfied: librosa==0.9.1 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (0.9.1)
# Requirement already satisfied: joblib>=0.14 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from librosa==0.9.1) (1.1.1)
# Requirement already satisfied: resampy>=0.2.2 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from librosa==0.9.1) (0.4.2)
# Requirement already satisfied: numba>=0.45.1 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from librosa==0.9.1) (0.56.4)
# Requirement already satisfied: pooch>=1.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from librosa==0.9.1) (1.4.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from librosa==0.9.1) (1.2.1)
# Requirement already satisfied: scipy>=1.2.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from librosa==0.9.1) (1.10.0)
# Requirement already satisfied: audioread>=2.1.5 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from librosa==0.9.1) (3.0.0)
# Requirement already satisfied: numpy>=1.17.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from librosa==0.9.1) (1.23.5)
# Requirement already satisfied: soundfile>=0.10.2 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from librosa==0.9.1) (0.12.1)
# Requirement already satisfied: decorator>=4.0.10 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from librosa==0.9.1) (5.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from librosa==0.9.1) (22.0)
# Requirement already satisfied: setuptools in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from numba>=0.45.1->librosa==0.9.1) (65.6.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from numba>=0.45.1->librosa==0.9.1) (0.39.1)
# Requirement already satisfied: requests in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from pooch>=1.0->librosa==0.9.1) (2.28.1)
# Requirement already satisfied: appdirs in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from pooch>=1.0->librosa==0.9.1) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.19.1->librosa==0.9.1) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from soundfile>=0.10.2->librosa==0.9.1) (1.15.1)
# Requirement already satisfied: pycparser in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.1) (2.21)
# Requirement already satisfied: idna<4,>=2.5 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa==0.9.1) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa==0.9.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa==0.9.1) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa==0.9.1) (1.26.14)

# %%
# check if matplotlib downgraded to 3.5 to enable subplots
print(librosa.__version__)
# Out:
# 0.9.1

# %%
# import modules needed
import sys  
from warnings import simplefilter # import warnings filter
from tensorflow.python.client import device_lib # check for GPU availability

# imports 
import tensorflow
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from matplotlib import pyplot
import matplotlib.pyplot
from keras.models import load_model
import numpy as np
from tqdm import tqdm

#import modules for file names
import glob

# import modules needed for audio processing
import librosa
import librosa.display
import IPython.display as ipd

# imports for feature transformation
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight
from tensorflow.keras.utils import to_categorical


simplefilter(action='ignore', category=FutureWarning) # ignore all future warnings
print("User Current Version:-", sys.version)
print(device_lib.list_local_devices())
# Out:
# User Current Version:- 3.10.9 (main, Mar  1 2023, 12:20:14) [Clang 14.0.6 ]
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11994611246484458493
# xla_global_id: -1
# ]

# %%
# Dataset details
# 264 recordings from 88 species
# using pandas read the 

birdsong = pd.read_csv('dataset/birdsong_metadata.csv')
birdsong = birdsong[["file_id", "english_cname"]] # only select 2 columns
# display the dataframe with columns extracted from the .csv 
birdsong
# Out:
#      file_id     english_cname
# 0     132608    Common Redpoll
# 1     132611    Common Redpoll
# 2      35068    Common Redpoll
# 3      82715     Marsh Warbler
# 4      64685     Marsh Warbler
# ..       ...               ...
# 259   132392       Song Thrush
# 260   146756       Song Thrush
# 261    27060  Northern Lapwing
# 262    97982  Northern Lapwing
# 263    69855  Northern Lapwing
#
# [264 rows x 2 columns]

# %%
# add the csv data to a dictionary, get the file_id as "keys" and the "english_cname" or the bird name as it's values
bird = birdsong.to_dict()
ids=list(bird['file_id'].values())
print('Number of instances: ',len(ids))
bird_name =list(bird['english_cname'].values())
# Out:
# Number of instances:  264

# %%
# slicing the wave files into smaller clips of 5seconds 
# all .flac bird sound files are located at working directory under dataset/recordings/*
dataset=[]
for filename in glob.iglob('dataset/recordings/*'):
    if (filename[-5:]=='.flac'):
        identity = filename.split('\\')[0][:-5]
        # Strip the first 21 characters
        identity = filename[21:]
        # Strip the last 5 characters
        identity = identity[:-5]
        index=ids.index(int(identity))
        label = bird_name[index]
        duration = librosa.get_duration(filename=filename)
        if duration>= 5: 
            slice_size = 5 #slice the first 5 seconds off
            iterations = int((duration-slice_size)/(slice_size - 1))
            iterations += 1
            # initial_offset is the starting point of the recording
            initial_offset = (duration - ((iterations*(slice_size-1)) + 1))/2 
            for i in range(iterations):
                # starting point of the slice from the initial_offset of the recording
                offset = initial_offset + i*(slice_size-1)
                dataset.append({"filename": filename, "label": label, "offset": offset})
dataset = pd.DataFrame(dataset)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4231 entries, 0 to 4230
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  4231 non-null   object
#  1   label     4231 non-null   object
#  2   offset    4231 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 99.3+ KB

# %%
# the sliced recordings offset values for each bird type as label, 
# offset values and correspoding filename displayed
dataset = dataset[dataset['label'].isin(list(dataset.label.value_counts()[:10].index))]
dataset.head(20)
# Out:
#                              filename           label     offset
# 122  dataset/recordings/xc146260.flac  Garden Warbler   0.770091
# 123  dataset/recordings/xc146260.flac  Garden Warbler   4.770091
# 124  dataset/recordings/xc146260.flac  Garden Warbler   8.770091
# 125  dataset/recordings/xc146260.flac  Garden Warbler  12.770091
# 126  dataset/recordings/xc146260.flac  Garden Warbler  16.770091
# 127  dataset/recordings/xc146260.flac  Garden Warbler  20.770091
# 128  dataset/recordings/xc146260.flac  Garden Warbler  24.770091
# 129  dataset/recordings/xc146260.flac  Garden Warbler  28.770091
# 130  dataset/recordings/xc146260.flac  Garden Warbler  32.770091
# 131  dataset/recordings/xc146260.flac  Garden Warbler  36.770091
# 132  dataset/recordings/xc146260.flac  Garden Warbler  40.770091
# 133  dataset/recordings/xc146260.flac  Garden Warbler  44.770091
# 134  dataset/recordings/xc146260.flac  Garden Warbler  48.770091
# 135  dataset/recordings/xc146260.flac  Garden Warbler  52.770091
# 136  dataset/recordings/xc146260.flac  Garden Warbler  56.770091
# 137  dataset/recordings/xc146260.flac  Garden Warbler  60.770091
# 138  dataset/recordings/xc146260.flac  Garden Warbler  64.770091
# 139  dataset/recordings/xc146260.flac  Garden Warbler  68.770091
# 140  dataset/recordings/xc146260.flac  Garden Warbler  72.770091
# 141  dataset/recordings/xc146260.flac  Garden Warbler  76.770091

# %%
# display the number of recording samples from the dataset per bird type
dataset.label.value_counts()
# Out:
# Corn Bunting          186
# Eurasian Skylark      143
# Common Nightingale    140
# Barn Swallow          131
# Sedge Warbler         125
# Common Linnet         124
# Garden Warbler        104
# Eurasian Wryneck       93
# Common Starling        92
# Common Chaffinch       89
# Name: label, dtype: int64

# %%
# display the graph with the dataset distribution
# show the bird names on the x-axis and the number of recordings per bird on the y-axis
pyplot.figure(figsize=(8,6), dpi=120)
dataset.label.value_counts().plot(kind='bar', title="Dataset distribution")
plt.show()

# %%
# Split the data into training and test samples, 80% for training and 20% for testing
train, test = train_test_split(dataset, test_size=0.2, random_state=123)
print("Train: %i" % len(train))
print("Test: %i" % len(test))
# Out:
# Train: 981
# Test: 246

# %%
# display the waveplots and the MFCC respectively for each of the 10 bird types
plt.figure(figsize=(10,40))
idx = 0
for label in dataset.label.unique():    
    y, sr = librosa.load(dataset[dataset.label==label].filename.iloc[1], duration=5)
    print(dataset[dataset.label==label].filename.iloc[1])
    
    # Wave plot
    idx+=1
    plt.subplot(10, 2, idx)
    plt.title("%s waveplot" % label,fontsize=10)
    librosa.display.waveshow(y, sr=sr)

    # MFCC 
    idx+=1
    mfccs = librosa.feature.mfcc(y,n_fft=255,hop_length=512,n_mfcc=13,n_mels=5)
    plt.subplot(10, 2, idx)
    librosa.display.specshow(mfccs,sr=sr,cmap='cool',hop_length=512, x_axis='time')
    plt.title("%s MFCC" % label,fontsize=10)
    plt.colorbar()

plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()
# Out:
# dataset/recordings/xc146260.flac
# dataset/recordings/xc102060.flac
# dataset/recordings/xc120664.flac
# dataset/recordings/xc157322.flac
# dataset/recordings/xc123167.flac
# dataset/recordings/xc123170.flac
# dataset/recordings/xc123808.flac
# dataset/recordings/xc42698.flac
# dataset/recordings/xc133054.flac
# dataset/recordings/xc42803.flac

# %%
# Extract mfcc features for each of the processed audio recordings
def extract_features(audio_path,offset):
    y, sr = librosa.load(audio_path, offset=offset, duration=5)
    # function is used to compute the MFCC's using librosa
    mfccs = librosa.feature.mfcc(y,n_fft=255,
                                 hop_length=512,
                                 n_mfcc=13,
                                 n_mels=5)
    return mfccs

# %%
x_train = []
x_test = []

# append the extracted features extracted for each recording from the "train" and "test" datasets
# into testing and training arrays

for idx in tqdm(range(len(train))):
    x_train.append(extract_features(train.filename.iloc[idx],train.offset.iloc[idx]))

for idx in tqdm(range(len(test))):
    x_test.append(extract_features(test.filename.iloc[idx],test.offset.iloc[idx]))
    
x_test = (np.asarray(x_test))
x_train = (np.asarray(x_train))

print("X train:", train.shape)
print("X test:", test.shape)
# Out:
# 100%|█████████████████████████████████████████| 981/981 [01:06<00:00, 14.77it/s]
# 100%|█████████████████████████████████████████| 246/246 [00:16<00:00, 14.87it/s]
# X train: (981, 3)
# X test: (246, 3)

# %%
# Encode Labels
encoder = LabelEncoder()
encoder.fit(train.label)

y_train = encoder.transform(train.label)
y_test = encoder.transform(test.label)

# Compute class weights
class_weights = class_weight.compute_class_weight(class_weight='balanced',classes = np.unique(y_train),y= y_train)

# %%
# x and y train and test shapes before reshaping
print("X train shape:", x_train.shape)
print("Y train shape:", y_train.shape)

print("X test shape:", x_test.shape)
print("Y train shape:", y_test.shape)
# Out:
# X train shape: (981, 5, 216)
# Y train shape: (981,)
# X test shape: (246, 5, 216)
# Y train shape: (246,)

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2])
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# x and y train and test shapes after reshaping
print("X train:", x_train.shape)
print("Y train:", y_train.shape)
print("X test:", x_test.shape)
print("Y test:", y_test.shape)
# Out:
# X train: (981, 5, 216)
# Y train: (981, 10)
# X test: (246, 5, 216)
# Y test: (246, 10)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from tensorflow.keras import regularizers

model = Sequential([
    LSTM(64, return_sequences=False, input_shape=(5,216),kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# PROVIDES MODEL SUMMARY
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 64)                71936
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 81546 (318.54 KB)
# Trainable params: 81546 (318.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# using adam optimizer with learning rate(lr) 10^-3
adam = tensorflow.keras.optimizers.Adam(learning_rate=0.001)
# compile model using categorical crossentropy, adam optimizer with lr 10^-3 and metrics for measuring results as "accuray"
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %%
# Train the model in 32 batches and for 100 epochs 
from datetime import datetime 
start = datetime.now()
history = model.fit(x_train, y_train,
              batch_size=32,
              epochs=100,
              validation_data=(x_test, y_test),
              shuffle=True)

duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 1s 8ms/step - loss: 4.4244 - accuracy: 0.1386 - val_loss: 4.0546 - val_accuracy: 0.2276
# Epoch 2/100
# 31/31 [==============================] - 0s 3ms/step - loss: 3.8428 - accuracy: 0.2691 - val_loss: 3.6123 - val_accuracy: 0.2846
# Epoch 3/100
# 31/31 [==============================] - 0s 3ms/step - loss: 3.3817 - accuracy: 0.3660 - val_loss: 3.3066 - val_accuracy: 0.3049
# Epoch 4/100
# 31/31 [==============================] - 0s 3ms/step - loss: 2.9970 - accuracy: 0.4373 - val_loss: 3.0538 - val_accuracy: 0.3415
# Epoch 5/100
# 31/31 [==============================] - 0s 3ms/step - loss: 2.6413 - accuracy: 0.5240 - val_loss: 2.8523 - val_accuracy: 0.3374
# Epoch 6/100
# 31/31 [==============================] - 0s 3ms/step - loss: 2.2789 - accuracy: 0.6279 - val_loss: 2.6785 - val_accuracy: 0.3496
# Epoch 7/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.9351 - accuracy: 0.7176 - val_loss: 2.5736 - val_accuracy: 0.3740
# Epoch 8/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.6309 - accuracy: 0.8104 - val_loss: 2.4670 - val_accuracy: 0.3862
# Epoch 9/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.4168 - accuracy: 0.8359 - val_loss: 2.4006 - val_accuracy: 0.3780
# Epoch 10/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.2007 - accuracy: 0.8909 - val_loss: 2.4165 - val_accuracy: 0.3699
# Epoch 11/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.1045 - accuracy: 0.8981 - val_loss: 2.4163 - val_accuracy: 0.3862
# Epoch 12/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9728 - accuracy: 0.9246 - val_loss: 2.4518 - val_accuracy: 0.3780
# Epoch 13/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.8691 - accuracy: 0.9490 - val_loss: 2.3812 - val_accuracy: 0.4350
# Epoch 14/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.7851 - accuracy: 0.9602 - val_loss: 2.3461 - val_accuracy: 0.4431
# Epoch 15/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.7539 - accuracy: 0.9480 - val_loss: 2.3489 - val_accuracy: 0.4431
# Epoch 16/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.7044 - accuracy: 0.9633 - val_loss: 2.3024 - val_accuracy: 0.4228
# Epoch 17/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6480 - accuracy: 0.9674 - val_loss: 2.1888 - val_accuracy: 0.4593
# Epoch 18/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6190 - accuracy: 0.9684 - val_loss: 2.2639 - val_accuracy: 0.4553
# Epoch 19/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6217 - accuracy: 0.9674 - val_loss: 2.3104 - val_accuracy: 0.4634
# Epoch 20/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5979 - accuracy: 0.9643 - val_loss: 2.2770 - val_accuracy: 0.4675
# Epoch 21/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5848 - accuracy: 0.9633 - val_loss: 2.4105 - val_accuracy: 0.4024
# Epoch 22/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6467 - accuracy: 0.9286 - val_loss: 2.3062 - val_accuracy: 0.4268
# Epoch 23/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6461 - accuracy: 0.9317 - val_loss: 2.2812 - val_accuracy: 0.4593
# Epoch 24/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6471 - accuracy: 0.9337 - val_loss: 2.5400 - val_accuracy: 0.3862
# Epoch 25/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6337 - accuracy: 0.9307 - val_loss: 2.4399 - val_accuracy: 0.4228
# Epoch 26/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5932 - accuracy: 0.9531 - val_loss: 2.5223 - val_accuracy: 0.4268
# Epoch 27/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5647 - accuracy: 0.9613 - val_loss: 2.4483 - val_accuracy: 0.4268
# Epoch 28/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5261 - accuracy: 0.9653 - val_loss: 2.3834 - val_accuracy: 0.4431
# Epoch 29/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5385 - accuracy: 0.9572 - val_loss: 2.3942 - val_accuracy: 0.4309
# Epoch 30/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5830 - accuracy: 0.9439 - val_loss: 2.5335 - val_accuracy: 0.4350
# Epoch 31/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5612 - accuracy: 0.9480 - val_loss: 2.6308 - val_accuracy: 0.4390
# Epoch 32/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5519 - accuracy: 0.9501 - val_loss: 2.5702 - val_accuracy: 0.4431
# Epoch 33/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5347 - accuracy: 0.9633 - val_loss: 2.5116 - val_accuracy: 0.4431
# Epoch 34/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4942 - accuracy: 0.9643 - val_loss: 2.6241 - val_accuracy: 0.4797
# Epoch 35/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4977 - accuracy: 0.9613 - val_loss: 2.5068 - val_accuracy: 0.4512
# Epoch 36/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5071 - accuracy: 0.9562 - val_loss: 2.6146 - val_accuracy: 0.4106
# Epoch 37/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4804 - accuracy: 0.9684 - val_loss: 2.4665 - val_accuracy: 0.4472
# Epoch 38/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4651 - accuracy: 0.9735 - val_loss: 2.3799 - val_accuracy: 0.4837
# Epoch 39/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4432 - accuracy: 0.9755 - val_loss: 2.4400 - val_accuracy: 0.4472
# Epoch 40/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4407 - accuracy: 0.9715 - val_loss: 2.4537 - val_accuracy: 0.4593
# Epoch 41/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4438 - accuracy: 0.9715 - val_loss: 2.4799 - val_accuracy: 0.4553
# Epoch 42/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4336 - accuracy: 0.9745 - val_loss: 2.6746 - val_accuracy: 0.4390
# Epoch 43/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4426 - accuracy: 0.9633 - val_loss: 2.6677 - val_accuracy: 0.4593
# Epoch 44/100
# 31/31 [==============================] - 0s 8ms/step - loss: 0.4683 - accuracy: 0.9531 - val_loss: 2.5925 - val_accuracy: 0.4472
# Epoch 45/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4686 - accuracy: 0.9521 - val_loss: 2.7610 - val_accuracy: 0.4350
# Epoch 46/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4565 - accuracy: 0.9653 - val_loss: 2.6875 - val_accuracy: 0.4431
# Epoch 47/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4413 - accuracy: 0.9664 - val_loss: 2.7504 - val_accuracy: 0.4146
# Epoch 48/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4669 - accuracy: 0.9541 - val_loss: 2.7797 - val_accuracy: 0.4228
# Epoch 49/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4282 - accuracy: 0.9653 - val_loss: 2.6229 - val_accuracy: 0.4593
# Epoch 50/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4459 - accuracy: 0.9623 - val_loss: 2.7255 - val_accuracy: 0.4268
# Epoch 51/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4533 - accuracy: 0.9582 - val_loss: 2.7184 - val_accuracy: 0.4512
# Epoch 52/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4444 - accuracy: 0.9592 - val_loss: 2.6631 - val_accuracy: 0.4756
# Epoch 53/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4621 - accuracy: 0.9541 - val_loss: 2.6350 - val_accuracy: 0.5041
# Epoch 54/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4265 - accuracy: 0.9725 - val_loss: 2.7274 - val_accuracy: 0.4634
# Epoch 55/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4158 - accuracy: 0.9694 - val_loss: 2.7026 - val_accuracy: 0.4675
# Epoch 56/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5063 - accuracy: 0.9419 - val_loss: 2.6092 - val_accuracy: 0.4268
# Epoch 57/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4845 - accuracy: 0.9521 - val_loss: 2.8326 - val_accuracy: 0.4309
# Epoch 58/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5087 - accuracy: 0.9388 - val_loss: 2.9443 - val_accuracy: 0.4065
# Epoch 59/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4849 - accuracy: 0.9470 - val_loss: 2.6927 - val_accuracy: 0.4472
# Epoch 60/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4828 - accuracy: 0.9562 - val_loss: 2.7859 - val_accuracy: 0.4390
# Epoch 61/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4560 - accuracy: 0.9592 - val_loss: 2.7202 - val_accuracy: 0.4350
# Epoch 62/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4468 - accuracy: 0.9684 - val_loss: 2.7759 - val_accuracy: 0.4797
# Epoch 63/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4094 - accuracy: 0.9817 - val_loss: 2.9055 - val_accuracy: 0.4512
# Epoch 64/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4094 - accuracy: 0.9735 - val_loss: 2.9144 - val_accuracy: 0.4309
# Epoch 65/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4057 - accuracy: 0.9725 - val_loss: 2.9098 - val_accuracy: 0.4431
# Epoch 66/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3792 - accuracy: 0.9776 - val_loss: 2.9080 - val_accuracy: 0.4675
# Epoch 67/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4017 - accuracy: 0.9664 - val_loss: 2.7947 - val_accuracy: 0.4634
# Epoch 68/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3619 - accuracy: 0.9867 - val_loss: 2.8137 - val_accuracy: 0.4715
# Epoch 69/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3597 - accuracy: 0.9847 - val_loss: 3.0553 - val_accuracy: 0.4512
# Epoch 70/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3718 - accuracy: 0.9755 - val_loss: 2.7995 - val_accuracy: 0.4390
# Epoch 71/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3846 - accuracy: 0.9694 - val_loss: 2.8904 - val_accuracy: 0.4634
# Epoch 72/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4067 - accuracy: 0.9613 - val_loss: 2.6935 - val_accuracy: 0.5163
# Epoch 73/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3970 - accuracy: 0.9715 - val_loss: 2.9170 - val_accuracy: 0.4472
# Epoch 74/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4329 - accuracy: 0.9562 - val_loss: 3.0112 - val_accuracy: 0.4146
# Epoch 75/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4476 - accuracy: 0.9562 - val_loss: 3.1005 - val_accuracy: 0.4472
# Epoch 76/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4291 - accuracy: 0.9623 - val_loss: 2.9975 - val_accuracy: 0.4837
# Epoch 77/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4189 - accuracy: 0.9613 - val_loss: 2.9283 - val_accuracy: 0.4472
# Epoch 78/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4660 - accuracy: 0.9511 - val_loss: 2.9584 - val_accuracy: 0.4634
# Epoch 79/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4293 - accuracy: 0.9664 - val_loss: 2.9298 - val_accuracy: 0.4675
# Epoch 80/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4259 - accuracy: 0.9592 - val_loss: 3.0770 - val_accuracy: 0.4634
# Epoch 81/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4270 - accuracy: 0.9664 - val_loss: 2.9106 - val_accuracy: 0.4715
# Epoch 82/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4159 - accuracy: 0.9715 - val_loss: 2.8619 - val_accuracy: 0.4593
# Epoch 83/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3742 - accuracy: 0.9796 - val_loss: 2.8612 - val_accuracy: 0.4878
# Epoch 84/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3755 - accuracy: 0.9776 - val_loss: 2.8329 - val_accuracy: 0.4837
# Epoch 85/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3649 - accuracy: 0.9827 - val_loss: 2.9031 - val_accuracy: 0.4431
# Epoch 86/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4037 - accuracy: 0.9643 - val_loss: 2.6559 - val_accuracy: 0.4837
# Epoch 87/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3847 - accuracy: 0.9735 - val_loss: 2.6136 - val_accuracy: 0.5163
# Epoch 88/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3809 - accuracy: 0.9745 - val_loss: 2.7205 - val_accuracy: 0.5041
# Epoch 89/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4290 - accuracy: 0.9592 - val_loss: 2.8390 - val_accuracy: 0.4919
# Epoch 90/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4522 - accuracy: 0.9460 - val_loss: 3.0703 - val_accuracy: 0.4675
# Epoch 91/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4025 - accuracy: 0.9684 - val_loss: 3.1811 - val_accuracy: 0.4431
# Epoch 92/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4492 - accuracy: 0.9450 - val_loss: 2.9843 - val_accuracy: 0.4675
# Epoch 93/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4724 - accuracy: 0.9480 - val_loss: 3.1183 - val_accuracy: 0.4512
# Epoch 94/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5039 - accuracy: 0.9460 - val_loss: 3.1807 - val_accuracy: 0.4675
# Epoch 95/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4510 - accuracy: 0.9664 - val_loss: 3.0291 - val_accuracy: 0.4593
# Epoch 96/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4489 - accuracy: 0.9674 - val_loss: 2.9268 - val_accuracy: 0.4756
# Epoch 97/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4097 - accuracy: 0.9715 - val_loss: 2.9707 - val_accuracy: 0.4797
# Epoch 98/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3940 - accuracy: 0.9817 - val_loss: 2.7229 - val_accuracy: 0.5122
# Epoch 99/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3931 - accuracy: 0.9806 - val_loss: 2.9142 - val_accuracy: 0.4797
# Epoch 100/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3518 - accuracy: 0.9867 - val_loss: 2.8852 - val_accuracy: 0.5041
# Training completed in time:  0:00:09.573661

# %%
# Loss Curves
plt.figure(figsize=[14,10])
plt.subplot(211)
plt.plot(history.history['loss'],'#d62728',linewidth=3.0)
plt.plot(history.history['val_loss'],'#1f77b4',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
 
# Accuracy Curves
plt.figure(figsize=[14,10])
plt.subplot(212)
plt.plot(history.history['accuracy'],'#d62728',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'#1f77b4',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
# get accuracy score for the model 
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 8/8 [==============================] - 0s 1ms/step - loss: 2.8852 - accuracy: 0.5041
# Test loss: 2.8852334022521973
# Test accuracy: 0.5040650367736816

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
# Display precision,f1 score,recall scores

predictions = model.predict(x_test, verbose=1)

y_true, y_pred = [],[]
classes = encoder.classes_
for idx, prediction in enumerate(predictions): 
    y_true.append(classes[np.argmax(y_test[idx])])
    y_pred.append(classes[np.argmax(prediction)])
    
print(classification_report(y_pred, y_true))
# Out:
# 8/8 [==============================] - 0s 1ms/step
#                     precision    recall  f1-score   support
#
#       Barn Swallow       0.63      0.49      0.55        35
#   Common Chaffinch       0.19      0.17      0.18        23
#      Common Linnet       0.52      0.64      0.57        22
# Common Nightingale       0.40      0.29      0.33        42
#    Common Starling       0.64      0.88      0.74         8
#       Corn Bunting       0.42      0.50      0.46        36
#   Eurasian Skylark       0.27      0.50      0.35        14
#   Eurasian Wryneck       1.00      0.76      0.86        29
#     Garden Warbler       0.38      0.50      0.43        10
#      Sedge Warbler       0.69      0.67      0.68        27
#
#           accuracy                           0.50       246
#          macro avg       0.51      0.54      0.52       246
#       weighted avg       0.53      0.50      0.51       246

# %%
classes
# Out:
# array(['Barn Swallow', 'Common Chaffinch', 'Common Linnet',
#        'Common Nightingale', 'Common Starling', 'Corn Bunting',
#        'Eurasian Skylark', 'Eurasian Wryneck', 'Garden Warbler',
#        'Sedge Warbler'], dtype=object)

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

confusion_matrix = metrics.confusion_matrix(y_true, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels=classes)
fig, ax = plt.subplots(figsize=(8, 6))
cm_display.plot(ax=ax)
# Rotate the x-axis labels to make them vertical
plt.xticks(rotation=90)
plt.show()

# %%
model_name = "birdSoundClassifier.h5"
model.save(model_name)
# Out:
# /Users/srijachatterjee/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# load model
from keras.models import load_model
model = load_model("birdSoundClassifier.h5")

# %%
# load and evaluate a saved model
# File path for the recording we want to be classy

classify_file = "dataset/recordings/xc123168.flac"
x_test = []
x_test.append(extract_features(classify_file,0.5))
x_test = np.asarray(x_test)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)
pred = model.predict(x_test,verbose=1)
print(pred)
# Out:
# 1/1 [==============================] - 0s 114ms/step
# [[1.0242463e-03 5.0828145e-05 3.4521120e-03 5.8864309e-05 7.1209317e-05
#   9.9493909e-01 1.2684763e-04 3.0174228e-06 2.9778141e-05 2.4399671e-04]]

# %%
# predict a sample using the trained model
pred_class = model.predict(x_test)
index = np.argmax(pred_class, axis=1)
print(classes[index])
# Out:
# 1/1 [==============================] - 0s 15ms/step
# ['Corn Bunting']

# %%
# verify the bird name using it's file_id
actual = birdsong.loc[birdsong['file_id'] == 123168]
actual
# Out:
#     file_id english_cname
# 84   123168  Corn Bunting
